# %%
# import libraries

import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

import time
import requests
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### In each product detail page, search for the product page url and then go into the page.

# %%
def get_product_links(website):
    
    links = []
    for page in range(1, 11):
        print("Processing page : {}".format(page))
        wd = webdriver.Chrome('chromedriver.exe')
        wd.get(website+"?p={}".format(page))
        time.sleep(5)
        product = wd.find_elements_by_class_name('product-item-link')
        
        for i in range(len(product)):
            links.append(product[i].get_attribute('href'))
        wd.close()
        
    print("Finish")
    return links

# %%
product_link = get_product_links("https://www.senheng.com.my/all-products/home-entertainment.html")
# Out:
# Processing page : 1
# Processing page : 2
# Processing page : 3
# Processing page : 4
# Processing page : 5
# Processing page : 6
# Processing page : 7
# Processing page : 8
# Processing page : 9
# Processing page : 10
# Finish

# %%
len(product_link)
# Out:
# 433

# %%
pd_links = list(set(product_link))

# %%
len(pd_links)
# Out:
# 252

# %%
SKU = []
category = []
status = []
price = []
rating = []
comments = []

for web in pd_links:
    wd = webdriver.Chrome('chromedriver.exe')
    wd.get(web)
    time.sleep(5)
    SKU.append(wd.find_element_by_class_name('base').text)
    category.append(wd.find_element_by_xpath('/html/body/div[2]/div[4]/ul/li[5]').text)
    status.append(wd.find_element_by_xpath('//*[@id="maincontent"]/div[2]/div/div/div/div[3]/div[2]/div/div[2]').text)
    price.append(wd.find_element_by_xpath('//*[@id="maincontent"]/div[2]/div/div/div/div[3]/div[1]/div[1]/span[1]').text)
    rating.append(wd.find_elements_by_class_name('cont__count-rating')[1].text[0])
    comment_list = wd.find_elements_by_class_name('review-content')
    if len(comment_list) == 0:
        comments.append('-')
    else:
        com_lst = []
        for i in range(len(comment_list)):
            com_lst.append(comment_list[i].text)
        comments.append(com_lst)
    wd.close()

# %%
print(len(SKU), len(category), len(status), len(price), len(rating), len(comments))
# Out:
# 252 252 252 252 252 252

# %% [markdown]
# ### Data Cleaning and labelling

# %%
product_info = pd.DataFrame([SKU, category, status, price, rating, comments]).T

# %%
product_info.columns = ['Product_Name', 'Category', 'Status', 'Price_RM', 'Rating', 'Comment']

# %%
def clean_text(text):
    text = text.replace(',', '')
    text = re.sub(r'[^0-9.\-]', '', text)
    return text

# %%
product_info['Price_RM'] = product_info['Price_RM'].apply(clean_text)
product_info['Price_RM'] = product_info['Price_RM'].astype(float)
product_info['Rating'] = product_info['Rating'].astype(float)
product_info['Status'] = product_info['Status'].replace('BUY NOW', 'AVAILABLE')

# %%
def get_brand(product):
    brand = product.split()[0]
    return brand

# %%
product_info['Brand'] = product_info['Product_Name'].apply(get_brand)

# %%
def comment_count(comment):
    if comment == '-':
        return 0
    else:
        return len(comment)

# %%
product_info['Comment_num'] = product_info['Comment'].apply(comment_count)

# %%
product_info[product_info['Comment'] != '-']
# Out:
#                                           Product_Name         Category  \
# 11   LG UN73 Series 55” 4K Active HDR Smart UHD TV ...               TV
# 16   Samsung 65 Inches Q60T QLED 4K UHD HDR Smart T...               TV
# 18                Samsung 2.1 Channel HW-T550 Soundbar            Audio
# 20   LG 75 Inch UN72 Series Active HDR Smart UHD TV...               TV
# 57      AVAILABLE    1199.0     5.0
# 58   OUT OF STOCK    3249.0     4.0
# 60      AVAILABLE    4249.0     5.0
# 66   OUT OF STOCK    2899.0     5.0
# 88      AVAILABLE    2588.0     5.0
# 93   OUT OF STOCK    1666.0     5.0
# 109  OUT OF STOCK    1599.0     4.0
# 111     AVAILABLE    2199.0     5.0
# 112     AVAILABLE    6599.0     5.0
# 120     AVAILABLE    1888.0     5.0
# 123     AVAILABLE    3999.0     5.0
# 133  OUT OF STOCK    4259.0     5.0
# 134     AVAILABLE     799.0     5.0
# 143     AVAILABLE    8999.0     5.0
# 156     AVAILABLE    3599.0     5.0
# 168     AVAILABLE   17999.0     5.0
# 173  OUT OF STOCK    3499.0     5.0
# 197     AVAILABLE    2399.0     4.0
# 199     AVAILABLE    4249.0     4.0
# 203     AVAILABLE    7999.0     5.0
# 214  OUT OF STOCK    3799.0     5.0
# 217     AVAILABLE    1599.0     4.0
# 227     AVAILABLE    1599.0     5.0
# 229     AVAILABLE     379.0     5.0
# 233     AVAILABLE    2099.0     5.0
# 236     AVAILABLE    8299.0     5.0
# 245  OUT OF STOCK    1349.0     5.0
# 248     AVAILABLE    5199.0     5.0
# 249     AVAILABLE     699.0     5.0
#
#                                                Comment    Brand  Comment_num
# 11   [Good#SenhengKOC,#31Anniversary, Good service ...       LG           10
# 16          [Helpful staff #31Anniversary,#SenhengKOC]  Samsung            1
# 18   [service baik#31Anniversary,#SenhengKOC, Fast ...  Samsung            2
# 20   [I bought this television about a month ago. H...       LG            1
# 22   [Great reccomrndations by salesperson#31Annive...  Samsung            2
# 31   [The remote is easy to use and was able to con...       LG            2
# 32   [I. Love. This. TV. It is, by far, the best TV...       LG            1
# 38   [Good service and staff friendly #Grandsenheng...     Sony            1
# 46   [The Feature that crowns it all for me is the ...       LG            1
# 48   [best price form senheng #senhengPOKOKMANGGA#3...  Samsung            7
# 57   [Bought it on 24 Dec 2020 at Bangi Outlet. Jus...    Sharp            1
# 58   [terbaik buat game/family movie/connected to p...     Sony            1
# 60   [Purchased TV from 2 years ago and now get a n...  Samsung            4
# 66   [Enjoy extra 1 year warranty #grand senheng ba...     Sony            1
# 88   [Good service #grandsenhengtemerloh#31Annivers...     Sony            5
# 93   [Senheng 1lagenda melaka good service#31Annive...  Samsung            8
# 109  [Pros :\nGot 3 hdmi\nGood service by senheng\n...    Haier            1
# 111  [ðŸ¤©ðŸ¤©ðŸ¤©#31Anniversary,#SenhengKOC, Extra...       LG            4
# 112  [Find out that the picture is very satisfying....       LG            2
# 120  [Transitions are smooth. Very low latency. Aud...     Sony            6
# 123  [I never thought I would own a TV that was cap...       LG            1
# 133  [Terima kasih senheng#SenhengKOC#Senhengkangar...     Sony            1
# 134  [Best service at senheng pokok mangga#SenhengK...     Sony            5
# 143  [Bought this a month ago and it’s the best inv...       LG            2
# 156  [Extra warranty at senheng#31Anniversary,#Senh...       LG            5
# 168  [I purchased this a week ago , very good quali...       LG            2
# 173  [undefined#31Anniversary,#SenhengKOC, Good ser...  Samsung            4
# 197  [It is an okay overall TV. Its providing wide ...       LG            2
# 199  [Goodservice #senQ #suteramall #Johor#31Annive...       LG            4
# 203  [Efficient service senheng temerloh#31Annivers...     Sony            1
# 214  [Great promotions and good services #SENHENGFA...     Sony            1
# 217  [Good job #31Anniversary,#SenhengKOC, save mon...       LG            6
# 227  [Wide range of electrical and electronic produ...     Sony            1
# 229  [servicegood#happyatsenheng#senhengbukitmertaj...     Sony            1
# 233  [Grand senheng pandamaran good service #senhen...     Sony            1
# 236  [Bought this about a month ago and have been v...       LG            1
# 245                   [good#31Anniversary,#SenhengKOC]     Sony            1
# 248  [I've purchased my TV for my family. This TV c...       LG            1
# 249  [Good service #grandsenhengtemerloh#31Annivers...     Sony            4

# %%
product_info.columns
# Out:
# Index(['Product_Name', 'Category', 'Status', 'Price_RM', 'Rating', 'Comment',
#        'Brand', 'Comment_num'],
#       dtype='object')

# %%
product_info = product_info[['Product_Name', 'Brand', 'Category', 'Status', 'Price_RM', 'Rating', 'Comment', 'Comment_num']]

# %%
product_info
# Out:
#                                           Product_Name       Brand  \
# 0     MasterLink Adjustable HDMI Cable 2M MSL-HD02-360  MasterLink
# 1                   Sharp 32-Inch Full HD TV 2TC32BD1X       Sharp
# 2    Belkin 1 Meters High Speed HDMI® Cable with Et...      Belkin
# 3                  MasterLink HDMI Cable 2M MSL-HD02SM  MasterLink
# 4              Haier 32-Inch Full HD LED TV LE32B9600T       Haier
# ..                                                 ...         ...
# 247  Sony Extra Bass In-Ear Headphones (Red) - SNY-...        Sony
# 248  LG NANO86 55’’ NanoCell 4K Smart TV with AI Th...          LG
# 249  Sony 2.1ch Soundbar with powerful wireless sub...        Sony
# 250  Hisense 43 Inch Full HD Android A6000F Series ...     Hisense
# 251  Sony Extra Bass On-Ear Headphones (Red) - SNY-...        Sony
#
#                Category        Status  Price_RM  Rating  \
# 0    Mobile Accessories     AVAILABLE     165.0     0.0
# 1                    TV     AVAILABLE     779.0     0.0
# 2           Accessories  OUT OF STOCK      46.0     0.0
# 3    Mobile Accessories     AVAILABLE     165.0     0.0
# 4                    TV  OUT OF STOCK     699.0     0.0
# ..                  ...           ...       ...     ...
# 247               Audio  OUT OF STOCK     169.0     0.0
# 248                  TV     AVAILABLE    5199.0     5.0
# 249               Audio     AVAILABLE     699.0     5.0
# 250                  TV  OUT OF STOCK    1199.0     0.0
# 251               Audio  OUT OF STOCK     195.0     0.0
#
#                                                Comment  Comment_num
# 0                                                    -            0
# 1                                                    -            0
# 2                                                    -            0
# 3                                                    -            0
# 4                                                    -            0
# ..                                                 ...          ...
# 247                                                  -            0
# 248  [I've purchased my TV for my family. This TV c...            1
# 249  [Good service #grandsenhengtemerloh#31Annivers...            4
# 250                                                  -            0
# 251                                                  -            0
#
# [252 rows x 8 columns]

# %% [markdown]
# ### Save into csv format.

# %%
product_info.to_csv('senheng_home_entertainment.csv', index=False)

# %%
product_info = pd.read_csv('senheng_home_entertainment.csv')
